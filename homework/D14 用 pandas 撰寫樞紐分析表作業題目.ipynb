# %% [markdown]
# 作業目標:<br>
# 1. 熟悉索引與欄位設定
# 2. 使用樞紐建立新資料

# %% [markdown]
# 作業重點:<br>
# 1. 多維度索引、欄位是有順序性的須注意
# 2. 使用樞紐建立資料需要注意參數<br>
#   index : 新資料的索引名稱<br>
#   columns : 新資料的欄位名稱<br>
#   values :新資料的值名稱

# %% [markdown]
# 題目: 運用下列分數資料重新建構資料，將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score<br><br>
# score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
import pandas as pd
import numpy as np
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','sex','class','chinese_score','english_score','math_score'])

# %%
score_df
# Out:
#     student_id  sex  class  chinese_score english_score  math_score
# 0            1   50     80             70           boy           1
# 1            2   60     45             50           boy           2
# 2            3   98     43             55           boy           1
# 3            4   70     69             89           boy           2
# 4            5   56     79             60          girl           1
# 5            6   60     68             55          girl           2
# 6            7   45     70             77          girl           1
# 7            8   55     77             76          girl           2
# 8            9   25     57             60          girl           1
# 9           10   88     40             43          girl           3
# 10          11   25     60             45           boy           3
# 11          12   80     60             23           boy           3
# 12          13   20     90             66          girl           3
# ...

# %%
#score_df.columns(['chinese_score','english_score','math_score'])

# %%
#將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score

# %%
score_df=score_df.set_index(['sex','class','student_id'],)
score_df
# Out:
#                       chinese_score english_score  math_score
# sex class student_id
# 50  80    1                      70           boy           1
# 60  45    2                      50           boy           2
# 98  43    3                      55           boy           1
# 70  69    4                      89           boy           2
# 56  79    5                      60          girl           1
# 60  68    6                      55          girl           2
# 45  70    7                      77          girl           1
# 55  77    8                      76          girl           2
# 25  57    9                      60          girl           1
# 88  40    10                     43          girl           3
# 25  60    11                     45           boy           3
# 80  60    12                     23           boy           3
# 20  90    13                     66          girl           3
# 50  50    14                     50          girl           3
# ...
